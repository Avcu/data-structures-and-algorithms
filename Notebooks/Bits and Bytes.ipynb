# %% [markdown]
# ## Playing with bits and bytes
#
# #### Sometimes one has to go deep and deal with the stored bits and bytes rather than variables. Here, I have some functions that might be useful in such cases.

# %% [markdown]
# ### Bin: returns the integer in binary format

# %%
a = 30
a_bin = bin(a)

print("a in binary: {}".format(a_bin))
print("Type: {}".format(type(a_bin)))
# Out:
# a in binary: 0b11110
# Type: <class 'str'>

# %% [markdown]
# ### `>>`: shifts the bits to the right

# %%
b = a >> 1

b_bin = bin(b)

print("a: {} and b: {}".format(a, b))
print("a in binary: {}".format(a_bin))
print("b in binary: {}".format(b_bin))
# Out:
# a: 30 and b: 15
# a in binary: 0b11110
# b in binary: 0b1111

# %% [markdown]
# ### `<<`: shifts the bits to the left

# %%
c = a << 1

c_bin = bin(c)

print("a: {} and c: {}".format(a, c))
print("a in binary: {}".format(a_bin))
print("c in binary: {}".format(c_bin))
# Out:
# a: 30 and c: 60
# a in binary: 0b11110
# c in binary: 0b111100

# %%
print(c)
print(bin(c))

cMinus = -c
print(bin(cMinus))
print(bin(cMinus & (2**31-1)))
# Out:
# 60
# 0b111100
# -0b111100
# 0b1111111111111111111111111000100

# %%
maxInt = int(-5)
print(maxInt)
print(bin(maxInt & (2**31-1)))


for idx in range(32):
    print("idx: {} and val: {}".format(idx, maxInt & 1))
    maxInt = maxInt >> 1
# Out:
# -5
# 0b1111111111111111111111111111011
# idx: 0 and val: 1
# idx: 1 and val: 1
# idx: 2 and val: 0
# idx: 3 and val: 1
# idx: 4 and val: 1
# idx: 5 and val: 1
# idx: 6 and val: 1
# idx: 7 and val: 1
# idx: 8 and val: 1
# idx: 9 and val: 1
# idx: 10 and val: 1
# idx: 11 and val: 1
# idx: 12 and val: 1
# idx: 13 and val: 1
# idx: 14 and val: 1
# idx: 15 and val: 1
# idx: 16 and val: 1
# idx: 17 and val: 1
# idx: 18 and val: 1
# idx: 19 and val: 1
# idx: 20 and val: 1
# idx: 21 and val: 1
# idx: 22 and val: 1
# idx: 23 and val: 1
# idx: 24 and val: 1
# idx: 25 and val: 1
# idx: 26 and val: 1
# idx: 27 and val: 1
# idx: 28 and val: 1
# idx: 29 and val: 1
# idx: 30 and val: 1
# idx: 31 and val: 1
